# %% [markdown]
# # Learning and Decision Making

# %% [markdown]
# ## Laboratory 2: Markov chains
#
# In the end of the lab, you should submit all code/answers written in the tasks marked as "Activity n. XXX", together with the corresponding outputs and any replies to specific questions posed to the e-mail <adi.tecnico@gmail.com>. Make sure that the subject is of the form [&lt;group n.&gt;] LAB &lt;lab n.&gt;.
#
# ### 1. Modeling
#
# Consider once again the simplified Monopoly game described in the Homework and for which you wrote a Markov chain model:
#
# <img src="monopoly.png" width="300px">
#
# Recall that your chain should describe a single player, where:
#
# * The player rolls a single die in each play;
# * The jail does not prevent the player from continuing to play. In other words, when landing on the “GO TO JAIL” cell, the player jumps back to the “JAIL” cell, but resumes play immediately.

# %% [markdown]
# ---
#
# #### Activity 1.
#
# Implement your Markov chain model in Python. In particular,
#
# * Create a list with all the states;
# * Define a `numpy` array with the corresponding transition probabilities.
#
# The order for the states used in the transition probability matrix should match that in the list of states.
#
# **Note 1**: Don't forget to import `numpy`.
#
# **Note 2**: Make sure to print the result in the end.
#
# ---

# %%
import numpy as np

states = ["COLLECT $200", "VERMONT AVENUE", 
          "JAIL", "VIRGINIA AVENUE", 
          "FREE PARKING", "MARVIN GARDENS", 
          "GO TO JAIL", "PENNSYLVANIA AVENUE"]

x = 1/6

P = np.array([[0, x ,x ,x ,x ,x ,x, 0], \
              [0, 0 ,x ,x ,x ,x ,x, x], \
              [x, 0 ,0 ,x ,x ,x ,x, x], \
              [x, x ,0 ,0 ,x ,x ,x, x], \
              [x, x ,x ,0 ,0 ,x ,x, x], \
              [x, x ,x ,x ,0 ,0 ,x, x], \
              [0, 0 ,1 ,0 ,0 ,0 ,0, 0], \
              [x, x ,x ,x ,x ,x ,0, 0]])

print(np.around(P, 5))
# Out:
# [[ 0.       0.16667  0.16667  0.16667  0.16667  0.16667  0.16667  0.     ]
#  [ 0.       0.       0.16667  0.16667  0.16667  0.16667  0.16667  0.16667]
#  [ 0.16667  0.       0.       0.16667  0.16667  0.16667  0.16667  0.16667]
#  [ 0.16667  0.16667  0.       0.       0.16667  0.16667  0.16667  0.16667]
#  [ 0.16667  0.16667  0.16667  0.       0.       0.16667  0.16667  0.16667]
#  [ 0.16667  0.16667  0.16667  0.16667  0.       0.       0.16667  0.16667]
#  [ 0.       0.       1.       0.       0.       0.       0.       0.     ]
#  [ 0.16667  0.16667  0.16667  0.16667  0.16667  0.16667  0.       0.     ]]

# %% [markdown]
# ---
#
# #### Activity 2.
#
# Compute the probability of the following trajectories:
#
# * "COLLECT \$200" - "VERMONT AVENUE" - "GO TO JAIL" - "JAIL"
# * "COLLECT \$200" - "GO TO JAIL" - "JAIL" - "COLLECT \$200"
# * "COLLECT \$200" - "PENNSYLVANIA AVENUE" - "COLLECT \$200"
#
# **Note:** Make sure to print the result in the end.
#
# ---

# %%
chain1 = ["COLLECT $200", "VERMONT AVENUE", "GO TO JAIL", "JAIL"]
chain2 = ["COLLECT $200", "GO TO JAIL", "JAIL", "COLLECT $200"]
chain3 = ["COLLECT $200", "PENNSYLVANIA AVENUE", "COLLECT $200"]

chains = [chain1, chain2, chain3]

for chain in chains:
    prob = 1
    for state in chain[:len(chain) -1]:
        current_state_index = states.index(state)
        next_state_index = states.index(chain[chain.index(state) + 1])
        prob = prob * P[current_state_index, next_state_index]
    print(chain, "- prob = %.3f" % prob)
# Out:
# ['COLLECT $200', 'VERMONT AVENUE', 'GO TO JAIL', 'JAIL'] - prob = 0.028
# ['COLLECT $200', 'GO TO JAIL', 'JAIL', 'COLLECT $200'] - prob = 0.028
# ['COLLECT $200', 'PENNSYLVANIA AVENUE', 'COLLECT $200'] - prob = 0.000

# %% [markdown]
# ### 2. Stability

# %% [markdown]
# ---
#
# #### Activity 3.
#
# Justify whether the chain implemented in Activity #1 is:
#
# * Irreducible
# * Aperiodic
# * Ergodic
#
# ---

# %% [markdown]
# The chain is irreducible since there is only one communicating class.
#
# It is Aperiodic since having an infinite combination number of moves to reach the state from where it departed the mdc =1 therefore it is aperiodic.
#
# Since ot is Irreductible and Aperiodic there is a stable destribution associated with this chain, making it an ergotic chain, also the eigenvalue and vector stuff.

# %% [markdown]
# ---
#
# #### Activity 4
#
# Compute the stationary distribution for the chain.
#
# **Note:** The stationary distribution is a *left* eigenvector of the transition probability matrix associated to the eigenvalue 1. As such, you may find useful the numpy function `numpy.linalg.eig`. Also, recall that the stationary distribution is *a distribution*.
#
# ---

# %%
#CENAS

# %% [markdown]
# ### 3. Simulation
#
# You are now going to *simulate* the Markov chain that you defined in Question #1.

# %% [markdown]
# ---
#
# #### Activity 5
#
# Generate a 10,000-step long trajectory of the chain defined in Activity #1.
#
# ---

# %%
from random import randint
trajectory = []
trajectory = trajectory + [states[randint(0,7)]]

for i in range(9999):
        possible_state = np.random.choice(states, size = 1,p =P[states.index(trajectory[-1])])
        trajectory = trajectory + [possible_state[0]]
print(trajectory)
# Out:
# ['FREE PARKING', 'COLLECT $200', 'VIRGINIA AVENUE', 'PENNSYLVANIA AVENUE', 'JAIL', 'COLLECT $200', 'FREE PARKING', 'GO TO JAIL', 'JAIL', 'PENNSYLVANIA AVENUE', 'MARVIN GARDENS', 'COLLECT $200', 'GO TO JAIL', 'JAIL', 'PENNSYLVANIA AVENUE', 'FREE PARKING', 'VERMONT AVENUE', 'JAIL', 'VIRGINIA AVENUE', 'PENNSYLVANIA AVENUE', 'MARVIN GARDENS', 'VIRGINIA AVENUE', 'PENNSYLVANIA AVENUE', 'VERMONT AVENUE', 'FREE PARKING', 'COLLECT $200', 'VIRGINIA AVENUE', 'PENNSYLVANIA AVENUE', 'MARVIN GARDENS', 'VERMONT AVENUE', 'FREE PARKING', 'COLLECT $200', 'JAIL', 'MARVIN GARDENS', 'VIRGINIA AVENUE', 'PENNSYLVANIA AVENUE', 'COLLECT $200', 'GO TO JAIL', 'JAIL', 'FREE PARKING', 'COLLECT $200', 'VIRGINIA AVENUE', 'GO TO JAIL', 'JAIL', 'PENNSYLVANIA AVENUE', 'COLLECT $200', 'JAIL', 'GO TO JAIL', 'JAIL', 'VIRGINIA AVENUE', 'FREE PARKING', 'VERMONT AVENUE', 'PENNSYLVANIA AVENUE', 'MARVIN GARDENS', 'VIRGINIA AVENUE', 'COLLECT $200', 'GO TO JAIL', 'JAIL', 'VIRGINIA AVENUE', 'GO TO JAIL', 'JAIL', 'COLLECT $200', 'FREE PARKING', 'JAIL', 'FREE PARKING', 'MARVIN GARDENS', 'VERMONT AVENUE', 'PENNSYLVANIA AVENUE', 'JAIL', 'FREE PARKING', 'MARVIN GARDENS', 'VIRGINIA AVENUE', 'FREE PARKING', 'JAIL', 'MARVIN GARDENS', 'VERMONT AVENUE', 'PENNSYLVANIA AVENUE', 'JAIL', 'GO TO JAIL', 'JAIL', 'MARVIN GARDENS', 'COLLECT $200', 'VIRGINIA AVENUE', 'PENNSYLVANIA AVENUE', 'JAIL', 'VIRGINIA AVENUE', 'VERMONT AVENUE', 'PENNSYLVANIA AVENUE', 'FREE PARKING', 'JAIL', 'FREE PARKING', 'PENNSYLVANIA AVENUE', 'VIRGINIA AVENUE', 'PENNSYLVANIA AVENUE', 'COLLECT $200', 'GO TO JAIL', 'JAIL', 'VIRGINIA AVENUE', 'MARVIN GARDENS', 'VERMONT AVENUE', 'VIRGINIA AVENUE', 'FREE PARKING', 'GO TO JAIL', 'JAIL', 'PENNSYLVANIA AVENUE', 'VERMONT AVENUE', 'JAIL', 'GO TO JAIL', 'JAIL', 'MARVIN GARDENS', 'JAIL', 'PENNSYLVANIA AVENUE', 'JAIL', 'GO TO JAIL', 'JAIL', 'MARVIN GARDENS', 'VIRGINIA AVENUE', 'MARVIN GARDENS', 'JAIL', 'COLLECT $200', 'MARVIN GARDENS', 'JAIL', 'MARVIN GARDENS', 'VERMONT AVENUE', 'FREE PARKING', 'PENNSYLVANIA AVENUE', 'VIRGINIA AVENUE', 'MARVIN GARDENS', 'GO TO JAIL', 'JAIL', 'FREE PARKING', 'PENNSYLVANIA AVENUE', 'VERMONT AVENUE', 'VIRGINIA AVENUE', 'MARVIN GARDENS', 'GO TO JAIL', 'JAIL', 'MARVIN GARDENS', 'GO TO JAIL', 'JAIL', 'PENNSYLVANIA AVENUE', 'VERMONT AVENUE', 'JAIL', 'MARVIN GARDENS', 'GO TO JAIL', 'JAIL', 'COLLECT $200', 'FREE PARKING', 'GO TO JAIL', 'JAIL', 'PENNSYLVANIA AVENUE', 'COLLECT $200', 'GO TO JAIL', 'JAIL', 'PENNSYLVANIA AVENUE', 'MARVIN GARDENS', 'PENNSYLVANIA AVENUE', 'FREE PARKING', 'MARVIN GARDENS', 'VERMONT AVENUE', 'FREE PARKING', 'GO TO JAIL', 'JAIL', 'VIRGINIA AVENUE', 'GO TO JAIL', 'JAIL', 'GO TO JAIL', 'JAIL', 'PENNSYLVANIA AVENUE', 'VERMONT AVENUE', 'PENNSYLVANIA AVENUE', 'JAIL', 'FREE PARKING', 'PENNSYLVANIA AVENUE', 'MARVIN GARDENS', 'COLLECT $200', 'FREE PARKING', 'JAIL', 'MARVIN GARDENS', 'JAIL', 'MARVIN GARDENS', 'PENNSYLVANIA AVENUE', 'COLLECT $200', 'FREE PARKING', 'PENNSYLVANIA AVENUE', 'COLLECT $200', 'GO TO JAIL', 'JAIL', 'MARVIN GARDENS', 'COLLECT $200', 'FREE PARKING', 'JAIL', 'FREE PARKING', 'COLLECT $200', 'GO TO JAIL', 'JAIL', 'VIRGINIA AVENUE', 'MARVIN GARDENS', 'VIRGINIA AVENUE', 'GO TO JAIL', 'JAIL', 'VIRGINIA AVENUE', 'COLLECT $200', 'JAIL', 'FREE PARKING', 'VERMONT AVENUE', 'MARVIN GARDENS', 'VIRGINIA AVENUE', 'MARVIN GARDENS', 'PENNSYLVANIA AVENUE', 'FREE PARKING', 'VERMONT AVENUE', 'MARVIN GARDENS', 'GO TO JAIL', 'JAIL', 'GO TO JAIL', 'JAIL', 'PENNSYLVANIA AVENUE', 'VERMONT AVENUE', 'JAIL', 'FREE PARKING', 'VERMONT AVENUE', 'VIRGINIA AVENUE', 'FREE PARKING', 'PENNSYLVANIA AVENUE', 'COLLECT $200', 'MARVIN GARDENS', 'VIRGINIA AVENUE', 'GO TO JAIL', 'JAIL', 'FREE PARKING', 'JAIL', 'PENNSYLVANIA AVENUE', 'JAIL', 'PENNSYLVANIA AVENUE', 'VIRGINIA AVENUE', 'COLLECT $200', 'VIRGINIA AVENUE', 'PENNSYLVANIA AVENUE', 'FREE PARKING', 'COLLECT $200', 'JAIL', 'COLLECT $200', 'JAIL', 'VIRGINIA AVENUE', 'COLLECT $200', 'FREE PARKING', 'PENNSYLVANIA AVENUE', 'MARVIN GARDENS', 'VIRGINIA AVENUE', 'GO TO JAIL', 'JAIL', 'GO TO JAIL', 'JAIL', 'CO ...

# %% [markdown]
# ---
#
# #### Activity 6
#
# Draw a histogram of the trajectory generated in Activity #5. Make sure that the histogram has one bin for each state. Compare the relative frequencies with the result of Activity #4.
#
# **Note**: Don't forget to load `matplotlib`.
#
# ---

# %%
import matplotlib.pyplot as plt
counts = np.zeros(8)
for state in trajectory:
    counts[states.index(state)] +=1
print (counts)
n, bins, patches = plt.hist(counts)
#gotta check out how to draw the plot
# Out:
# [ 1123.   898.  2174.  1118.  1100.  1222.  1295.  1070.]

# %% [markdown]
# The empirical distribution matches the theoretical distribution.
